# %%
import sys
sys.path.insert(1, '../')
import numpy as np

import MDAnalysis as mda
from MDAnalysis import analysis

import importlib
import XS_calc
from XS_calc import *

# %%
U = mda.Universe('../data/3v03.pdb')

# traj = Trajectory(U, selection='protein', ffdir='../form_factors/')
# mea = Measurement(q = np.linspace(0.00, 0.500, num=501))
# env = Environment(num_raster=200, c1=1.00, c2=0.00)

# print("frame_XS_calc_fast")
# frame_XS_calc_fast(traj.Frames[0], env, mea, timing=True)

traj = Trajectory(U, selection='protein', ffdir='../form_factors/')
mea = Measurement(q = np.linspace(0.00, 0.500, num=501))
env = Environment(num_raster=200, c1=1.00, c2=0.00)

print("frame_XS_calc_exp")
frame_XS_calc_exp(traj.Frames[0], env, mea, timing=True)
# Out:
# frame_XS_calc_exp
# SASA: 2029.98 ms
#   FF: 502.91 ms
# Xray: 21256.39 ms
# array([4.27756411e+08, 4.27547663e+08, 4.26922081e+08, 4.25881643e+08,
#        4.24429633e+08, 4.22570625e+08, 4.20310460e+08, 4.17656212e+08,
#        4.14616151e+08, 4.11199705e+08, 4.07417404e+08, 4.03280828e+08,
#        3.98802549e+08, 3.93996065e+08, 3.88875731e+08, 3.83456690e+08,
#        3.77754792e+08, 3.71786520e+08, 3.65568909e+08, 3.59119463e+08,
#        3.52456072e+08, 3.45596929e+08, 3.38560446e+08, 3.31365170e+08,
#        3.24029703e+08, 3.16572617e+08, 3.09012380e+08, 3.01367278e+08,
#        2.93655342e+08, 2.85894276e+08, 2.78101394e+08, 2.70293554e+08,
#        2.62487103e+08, 2.54697823e+08, 2.46940879e+08, 2.39230780e+08,
#        2.31581334e+08, 2.24005621e+08, 2.16515959e+08, 2.09123884e+08,
#        2.01840129e+08, 1.94674613e+08, 1.87636433e+08, 1.80733858e+08,
#        1.73974333e+08, 1.67364485e+08, 1.60910131e+08, 1.54616293e+08,
# ...
